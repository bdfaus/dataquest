# %%
import pandas as pd
import matplotlib as plt

# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')

# %%
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads[recent_grads['Median'] == recent_grads['Median'].median()]
# Out:
#     Rank  Major_code                                     Major    Total  \
# 86    87        6209  HUMAN RESOURCES AND PERSONNEL MANAGEMENT  24497.0
# 87    88        3202                 PRE-LAW AND LEGAL STUDIES  13528.0
# 88    89        6199  MISCELLANEOUS HEALTH MEDICAL PROFESSIONS  13386.0
# 89    90        5401                     PUBLIC ADMINISTRATION   5629.0
# 90    91        5005                               GEOSCIENCES   1978.0
# 91    92        5206                         SOCIAL PSYCHOLOGY   1386.0
#
#        Men    Women            Major_category  ShareWomen  Sample_size  \
# 86  6184.0  18313.0                  Business    0.747561          264
# 87  4435.0   9093.0       Law & Public Policy    0.672161           92
# 88  1589.0  11797.0                    Health    0.881294           81
# 89  2947.0   2682.0       Law & Public Policy    0.476461           46
# 90   809.0   1169.0         Physical Sciences    0.591001           18
# ...

# %%
recent_grads.head(2)
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
# 1           350               257             50
#
# [2 rows x 21 columns]

# %%
recent_grads[recent_grads['Major']=="PHILOSOPHY AND RELIGIOUS STUDIES"]
# Out:
#      Rank  Major_code                             Major    Total      Men  \
# 135   136        4801  PHILOSOPHY AND RELIGIOUS STUDIES  54814.0  31967.0
#
#        Women             Major_category  ShareWomen  Sample_size  Employed  \
# 135  22847.0  Humanities & Liberal Arts     0.41681          375     40157
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 135      ...            16659                 21816        4267
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 135           0.096052   32200  23000  47100         14444             20313
#
#      Low_wage_jobs
# 135           8051
#
# [1 rows x 21 columns]

# %%
recent_grads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
# Rank                    173 non-null int64
# Major_code              173 non-null int64
# Major                   173 non-null object
# Total                   172 non-null float64
# Men                     172 non-null float64
# Women                   172 non-null float64
# Major_category          173 non-null object
# ShareWomen              172 non-null float64
# Sample_size             173 non-null int64
# Employed                173 non-null int64
# Full_time               173 non-null int64
# Part_time               173 non-null int64
# Full_time_year_round    173 non-null int64
# Unemployed              173 non-null int64
# Unemployment_rate       173 non-null float64
# Median                  173 non-null int64
# P25th                   173 non-null int64
# P75th                   173 non-null int64
# College_jobs            173 non-null int64
# ...

# %%
raw_data_count = recent_grads.shape[0]

# %%
recent_grads = recent_grads.dropna()

# %%
cleaned_data_count = recent_grads.shape[0]

# %%
ax = recent_grads.plot(x='Sample_size',y='Employed',kind='scatter')
ax.set_title('Employed vs. Sample_size')

# %%
recent_grads.plot(x='Sample_size',y='Median',kind='scatter')

# %%
recent_grads.plot('Sample_size','Median','scatter')

# %%
recent_grads.plot('Full_time','Median','scatter')

# %%
recent_grads.plot('ShareWomen','Unemployment_rate','scatter')

# %%
recent_grads.plot('Men','Median','scatter')

# %%
recent_grads.plot('Women','Median','scatter')

# %% [markdown]
# There aren't very strong correlations in any of the above graphs

# %%
recent_grads['Sample_size'].hist(bins=25)

# %%
recent_grads['Median'].hist(bins=20)

# %%
recent_grads['Employed'].hist()

# %%
recent_grads['Full_time'].hist(bins=20)

# %%
recent_grads['Unemployment_rate'].hist(bins=20, range=(0,.2))

# %%
recent_grads['Percent_Women'] = (recent_grads['Women']/recent_grads['Total'] * 100)

# %%
recent_grads['Percent_Men'] = (recent_grads['Men']/recent_grads['Total'] * 100)

# %%
recent_grads.hist('Percent_Women')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa75e6524e0>]], dtype=object)

# %%
recent_grads.hist('Percent_Men')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa75e5e9cf8>]], dtype=object)

# %%
recent_grads.hist('Median')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6ff37a0b8>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6ff2f9dd8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6ff152400>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6ff0f8a20>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa6fee4da90>]], dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar')

# %%
recent_grads[:5].plot.bar(x='Major',y='Women')

# %%
low_pay = recent_grads.sort_values('Median')[0:10]

# %%
high_pay = recent_grads.sort_values('Median',ascending = False)[0:10]

# %%
ten_high_and_low = pd.concat([low_pay,high_pay])

# %%
ten_high_and_low.plot.bar(x='Major',y='ShareWomen')

# %% [markdown]
# <i>Use a grouped bar plot to compare the number of men with the number of women in each category of majors.</i>
# <i>Use a box plot to explore the distributions of median salaries and unemployment rate.</i>
# <i>Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.
